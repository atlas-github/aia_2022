arding the company s own testing methodologies whether through written materials or verbal explanations is tantamount to refusing mr musk s data requests twitter s effort to characterize it otherwise is merely an attempt to obfuscate and confuse the issue mr musk has made it clear that he does not believe the company s lax testing methodologies are adequate so he must conduct his own analysis the data he has requested is necessary to do so the letter later adds that if twitter is confident in its publicized spam estimates mr musk does not understand the company s reluctance to allow mr musk to independently evaluate those estimates musk faces a 1 billion fee if he calls off the 44 billion agreement to buy twitter a contract breach by twitter could change that penalty']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.tokenize import sent_tokenize
sent_tokenize(clean_news3)
# Out:
# ['tesla ceo elon musk is raising another obstacle in his 44 billion bid to buy twitter twtr in an sec filing released monday morning musk s counsel said twitter has not coughed up adequate data on the company s users committing a clear material breach of the company s obligations as part of its merger agreement based on twitter s behavior to date and the company s latest correspondence in particular mr musk believes the company is actively resisting and thwarting his information rights and the company s corresponding obligations under the merger agreement the letter reads this is a clear material breach of twitter s obligations under the merger agreement and mr musk reserves all rights resulting therefrom including his right not to consummate the transaction and his right to terminate the merger agreement twitter stock fell around 5 on the news musk s complaint stems from twitter s insistence that the social media platform does not have a problem with bots an issue that the world s richest person has flagged since announcing a deal to acquire twitter for 54 20 per share on april 25 shares of twitter have dropped more than 17 since the deal was announced in a statement to yahoo finance on monday a twitter spokesperson said twitter has and will continue to cooperatively share information with mr musk to consummate the transaction in accordance with the terms of the merger agreement we believe this agreement is in the best interest of all shareholders we intend to close the transaction and enforce the merger agreement at the agreed price and terms over the last several weeks musk has raised various concerns about twitter s user base challenging the veracity of the company s claims that just 5 of its reported users are bots in mid may musk famously responded to a thread from twitter ceo parag agrawal outlining the company s current processes with a poop emoji later that month musk said that the way twitter calculates the estimated number of bots on its platform is very suspicious musk s team now claims that twitter is not providing access to information that could get to the bottom of these claims noting that musk requested data from twitter in letters sent to the company on may 25 and may 31 twitter has in fact refused to provide the information that mr musk has repeatedly requested since may 9 2022 to facilitate his evaluation of spam and fake accounts on the company s platform monday s letter reads twitter s latest offer to simply provide additional details regarding the company s own testing methodologies whether through written materials or verbal explanations is tantamount to refusing mr musk s data requests twitter s effort to characterize it otherwise is merely an attempt to obfuscate and confuse the issue mr musk has made it clear that he does not believe the company s lax testing methodologies are adequate so he must conduct his own analysis the data he has requested is necessary to do so the letter later adds that if twitter is confident in its publicized spam estimates mr musk does not understand the company s reluctance to allow mr musk to independently evaluate those estimates musk faces a 1 billion fee if he calls off the 44 billion agreement to buy twitter a contract breach by twitter could change that penalty']

# %%
#Word tokenization
from nltk.tokenize import word_tokenize
tokens = word_tokenize(clean_news3)
tokens
# Out:
# ['tesla',
#  'ceo',
#  'elon',
#  'musk',
#  'is',
#  'raising',
#  'another',
#  'obstacle',
#  'in',
#  'his',
#  '44',
#  'billion',
#  'bid',
#  'to',
#  'buy',
#  'twitter',
#  'twtr',
#  'in',
#  'an',
#  'sec',
#  'filing',
#  'released',
#  'monday',
#  'morning',
#  'musk',
#  's',
#  'counsel',
#  'said',
#  'twitter',
#  'has',
#  'not',
#  'coughed',
#  'up',
#  'adequate',
#  'data',
#  'on',
#  'the',
#  'company',
#  's',
#  'users',
#  'committing',
#  'a',
#  'clear',
#  'material',
#  'breach',
#  'of',
#  'the',
#  'company',
#  's',
#  'obligations',
#  'as',
#  'part',
#  'of',
#  'its',
#  'merger',
#  'agreement',
#  'based',
#  'on',
#  'twitter',
#  's',
#  'behavior',
#  'to',
#  'date',
#  'and',
#  'the',
#  'company',
#  's',
#  'latest',
#  'correspondence',
#  'in',
#  'particular',
#  'mr',
#  'musk',
#  'believes',
#  'the',
#  'company',
#  'is',
#  'actively',
#  'resisting',
#  'and',
#  'thwarting',
#  'his',
#  'information',
#  'rights',
#  'and',
#  'the',
#  'company',
#  's',
#  'corresponding',
#  'obligations',
#  'under',
#  'the',
#  'merger',
#  'agreement',
#  'the',
#  'letter',
#  'reads',
#  'this',
#  'is',
#  'a',
#  'clear',
#  'material',
#  'breach',
#  'of',
#  'twitter',
#  's',
#  'obligations',
#  'under',
#  'the',
#  'merger',
#  'agreement',
#  'and',
#  'mr',
#  'musk',
#  'reserves',
#  'all',
#  'rights',
#  'resulting',
#  'therefrom',
#  'including',
#  'his',
#  'right',
#  'not',
#  'to',
#  'consummate',
#  'the',
#  'transaction',
#  'and',
#  'his',
#  'right',
#  'to',
#  'terminate',
#  'the',
#  'merger',
#  'agreement',
#  'twitter',
#  'stock',
#  'fell',
#  'around',
#  '5',
#  'on',
#  'the',
#  'news',
#  'musk',
#  's',
#  'complaint',
#  'stems',
#  'from',
#  'twitter',
#  's',
#  'insistence',
#  'that',
#  'the',
#  'social',
#  'media',
#  'platform',
#  'does',
#  'not',
#  'have',
#  'a',
#  'problem',
#  'with',
#  'bots',
#  'an',
#  'issue',
#  'that',
#  'the',
#  'world',
#  's',
#  'richest',
#  'person',
#  'has',
#  'flagged',
#  'since',
#  'announcing',
#  'a',
#  'deal',
#  'to',
#  'acquire',
#  'twitter',
#  'for',
#  '54',
#  '20',
#  'per',
#  'share',
#  'on',
#  'april',
#  '25',
#  'shares',
#  'of',
#  'twitter',
#  'have',
#  'dropped',
#  'more',
#  'than',
#  '17',
#  'since',
#  'the',
#  'deal',
#  'was',
#  'announced',
#  'in',
#  'a',
#  'statement',
#  'to',
#  'yahoo',
#  'finance',
#  'on',
#  'monday',
#  'a',
#  'twitter',
#  'spokesperson',
#  'said',
#  'twitter',
#  'has',
#  'and',
#  'will',
#  'continue',
#  'to',
#  'cooperatively',
#  'share',
#  'information',
#  'with',
#  'mr',
#  'musk',
#  'to',
#  'consummate',
#  'the',
#  'transaction',
#  'in',
#  'accordance',
#  'with',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'merger',
#  'agreement',
#  'we',
#  'believe',
#  'this',
#  'agreement',
#  'is',
#  'in',
#  'the',
#  'best',
#  'interest',
#  'of',
#  'all',
#  'shareholders',
#  'we',
#  'intend',
#  'to',
#  'close',
#  'the',
#  'transaction',
#  'and',
#  'enforce',
#  'the',
#  'merger',
#  'agreement',
#  'at',
#  'the',
#  'agreed',
#  'price',
#  'and',
#  'terms',
#  'over',
#  'the',
#  'last',
#  'several',
#  'weeks',
#  'musk',
#  'has',
#  'raised',
#  'various',
#  'concerns',
#  'about',
#  'twitter',
#  's',
#  'user',
#  'base',
#  'challenging',
#  'the',
#  'veracity',
#  'of',
#  'the',
#  'company',
#  's',
#  'claims',
#  'that',
#  'just',
#  '5',
#  'of',
#  'its',
#  'reported',
#  'users',
#  'are',
#  'bots',
#  'in',
#  'mid',
#  'may',
#  'musk',
#  'famously',
#  'responded',
#  'to',
#  'a',
#  'thread',
#  'from',
#  'twitter',
#  'ceo',
#  'parag',
#  'agrawal',
#  'outlining',
#  'the',
#  'company',
#  's',
#  'current',
#  'processes',
#  'with',
#  'a',
#  'poop',
#  'emoji',
#  'later',
#  'that',
#  'month',
#  'musk',
#  'said',
#  'that',
#  'the',
#  'way',
#  'twitter',
#  'calculates',
#  'the',
#  'estimated',
#  'number',
#  'of',
#  'bots',
#  'on',
#  'its',
#  'platform',
#  'is',
#  'very',
#  'suspicious',
#  'musk',
#  's',
#  'team',
#  'now',
#  'claims',
#  'that',
#  'twitter',
#  'is',
#  'not',
#  'providing',
#  'access',
#  'to',
#  'information',
#  'that',
#  'could',
#  'get',
#  'to',
#  'the',
#  'bottom',
#  'of',
#  'these',
#  'claims',
#  'noting',
#  'that',
#  'musk',
#  'requested',
#  'data',
#  'from',
#  'twitter',
#  'in',
#  'letters',
#  'sent',
#  'to',
#  'the',
#  'company',
#  'on',
#  'may',
#  '25',
#  'and',
#  'may',
#  '31',
#  'twitter',
#  'has',
#  'in',
#  'fact',
#  'refused',
#  'to',
#  'provide',
#  'the',
#  'information',
#  'that',
#  'mr',
#  'musk',
#  'has',
#  'repeatedly',
#  'requested',
#  'since',
#  'may',
#  '9',
#  '2022',
#  'to',
#  'facilitate',
#  'his',
#  'evaluation',
#  'of',
#  'spam',
#  'and',
#  'fake',
#  'accounts',
#  'on',
#  'the',
#  'company',
#  's',
#  'platform',
#  'monday',
#  's',
#  'letter',
#  'reads',
#  'twitter',
#  's',
#  'latest',
#  'offer',
#  'to',
#  'simply',
#  'provide',
#  'additional',
#  'details',
#  'regarding',
#  'the',
#  'company',
#  's',
#  'own',
#  'testing',
#  'methodologies',
#  'whether',
#  'through',
#  'written',
#  'materials',
#  'or',
#  'verbal',
#  'explanations',
#  'is',
#  'tantamount',
#  'to',
#  'refusing',
#  'mr',
#  'musk',
#  's',
#  'data',
#  'requests',
#  'twitter',
#  's',
#  'effort',
#  'to',
#  'characterize',
#  'it',
#  'otherwise',
#  'is',
#  'merely',
#  'an',
#  'attempt',
#  'to',
#  'obfuscate',
#  'and',
#  'confuse',
#  'the',
#  'issue',
#  'mr',
#  'musk',
#  'has',
#  'made',
#  'it',
#  'clear',
#  'that',
#  'he',
#  'does',
#  'not',
#  'believe',
#  'the',
#  'company',
#  's',
#  'lax',
#  'testing',
#  'methodologies',
#  'are',
#  'adequate',
#  'so',
#  'he',
#  'must',
#  'conduct',
#  'his',
#  'own',
#  'analysis',
#  'the',
#  'data',
#  'he',
#  'has',
#  'requested',
#  'is',
#  'necessary',
#  'to',
#  'do',
#  'so',
#  'the',
#  'letter',
#  'later',
#  'adds',
#  'that',
#  'if',
#  'twitter',
#  'is',
#  'confident',
#  'in',
#  'its',
#  'publicized',
#  'spam',
#  'estimates',
#  'mr',
#  'musk',
#  'does',
#  'not',
#  'understand',
#  'the',
#  'company',
#  's',
#  'reluctance',
#  'to',
#  'allow',
#  'mr',
#  'musk',
#  'to',
#  'independently',
#  'evaluate',
#  'those',
#  'estimates',
#  'musk',
#  'faces',
#  'a',
#  '1',
#  'billion',
#  'fee',
#  'if',
#  'he',
#  'calls',
#  'off',
#  'the',
#  '44',
#  'billion',
#  'agreement',
#  'to',
#  'buy',
#  'twitter',
#  'a',
#  'contract',
#  'breach',
#  'by',
#  'twitter',
#  'could',
#  'change',
#  'that',
#  'penalty']

# %%
#remove stopwords
url = 'https://raw.githubusercontent.com/theleadio/datascience_demo/master/stopwords.txt'
response = requests.get(url)
stopwords = response.text.splitlines()

tokens = [t for t in tokens if t not in stopwords and len(t) > 0]

from collections import Counter
counter = Counter(tokens).most_common(200)
counter
# Out:
# [('twitter', 21),
#  ('musk', 17),
#  ('company', 12),
#  ('agreement', 8),
#  ('merger', 6),
#  ('data', 4),
#  ('information', 4),
#  ('billion', 3),
#  ('monday', 3),
#  ('breach', 3),
#  ('obligations', 3),
#  ('letter', 3),
#  ('transaction', 3),
#  ('platform', 3),
#  ('bots', 3),
#  ('claims', 3),
#  ('requested', 3),
#  ('ceo', 2),
#  ('44', 2),
#  ('buy', 2),
#  ('adequate', 2),
#  ('users', 2),
#  ('material', 2),
#  ('rights', 2),
#  ('reads', 2),
#  ('consummate', 2),
#  ('5', 2),
#  ('issue', 2),
#  ('deal', 2),
#  ('share', 2),
#  ('25', 2),
#  ('terms', 2),
#  ('provide', 2),
#  ('spam', 2),
#  ('testing', 2),
#  ('methodologies', 2),
#  ('estimates', 2),
#  ('tesla', 1),
#  ('elon', 1),
#  ('raising', 1),
#  ('obstacle', 1),
#  ('bid', 1),
#  ('twtr', 1),
#  ('sec', 1),
#  ('filing', 1),
#  ('released', 1),
#  ('morning', 1),
#  ('counsel', 1),
#  ('coughed', 1),
#  ('committing', 1),
#  ('based', 1),
#  ('behavior', 1),
#  ('date', 1),
#  ('correspondence', 1),
#  ('believes', 1),
#  ('actively', 1),
#  ('resisting', 1),
#  ('thwarting', 1),
#  ('reserves', 1),
#  ('resulting', 1),
#  ('therefrom', 1),
#  ('including', 1),
#  ('terminate', 1),
#  ('stock', 1),
#  ('fell', 1),
#  ('news', 1),
#  ('complaint', 1),
#  ('stems', 1),
#  ('insistence', 1),
#  ('social', 1),
#  ('media', 1),
#  ('world', 1),
#  ('richest', 1),
#  ('person', 1),
#  ('flagged', 1),
#  ('announcing', 1),
#  ('acquire', 1),
#  ('54', 1),
#  ('20', 1),
#  ('april', 1),
#  ('shares', 1),
#  ('dropped', 1),
#  ('17', 1),
#  ('announced', 1),
#  ('statement', 1),
#  ('yahoo', 1),
#  ('finance', 1),
#  ('spokesperson', 1),
#  ('continue', 1),
#  ('cooperatively', 1),
#  ('accordance', 1),
#  ('shareholders', 1),
#  ('intend', 1),
#  ('close', 1),
#  ('enforce', 1),
#  ('agreed', 1),
#  ('price', 1),
#  ('weeks', 1),
#  ('raised', 1),
#  ('concerns', 1),
#  ('user', 1),
#  ('base', 1),
#  ('challenging', 1),
#  ('veracity', 1),
#  ('reported', 1),
#  ('mid', 1),
#  ('famously', 1),
#  ('responded', 1),
#  ('thread', 1),
#  ('parag', 1),
#  ('agrawal', 1),
#  ('outlining', 1),
#  ('current', 1),
#  ('processes', 1),
#  ('poop', 1),
#  ('emoji', 1),
#  ('month', 1),
#  ('calculates', 1),
#  ('estimated', 1),
#  ('suspicious', 1),
#  ('team', 1),
#  ('providing', 1),
#  ('access', 1),
#  ('bottom', 1),
#  ('noting', 1),
#  ('letters', 1),
#  ('31', 1),
#  ('refused', 1),
#  ('repeatedly', 1),
#  ('9', 1),
#  ('2022', 1),
#  ('facilitate', 1),
#  ('evaluation', 1),
#  ('fake', 1),
#  ('accounts', 1),
#  ('offer', 1),
#  ('simply', 1),
#  ('additional', 1),
#  ('details', 1),
#  ('written', 1),
#  ('materials', 1),
#  ('verbal', 1),
#  ('explanations', 1),
#  ('tantamount', 1),
#  ('refusing', 1),
#  ('requests', 1),
#  ('effort', 1),
#  ('characterize', 1),
#  ('attempt', 1),
#  ('obfuscate', 1),
#  ('confuse', 1),
#  ('lax', 1),
#  ('conduct', 1),
#  ('analysis', 1),
#  ('adds', 1),
#  ('confident', 1),
#  ('publicized', 1),
#  ('understand', 1),
#  ('reluctance', 1),
#  ('independently', 1),
#  ('evaluate', 1),
#  ('1', 1),
#  ('fee', 1),
#  ('calls', 1),
#  ('contract', 1),
#  ('change', 1),
#  ('penalty', 1)]

# %%
pd.set_option('max_rows', 200)

#Word frequency table
import pandas as pd
pd.DataFrame(counter, columns = ["word", "frequency"])
# Out:
#                word  frequency
# 0           twitter         21
# 1              musk         17
# 2           company         12
# 3         agreement          8
# 4            merger          6
# 5              data          4
# 6       information          4
# 7           billion          3
# 8            monday          3
# 9            breach          3
# 10      obligations          3
# 11           letter          3
# 12      transaction          3
# 13         platform          3
# 14             bots          3
# 15           claims          3
# 16        requested          3
# 17              ceo          2
# 18               44          2
# 19              buy          2
# 20         adequate          2
# 21            users          2
# 22         material          2
# 23           rights          2
# 24            reads          2
# 25       consummate          2
# 26                5          2
# 27            issue          2
# 28             deal          2
# 29            share          2
# 30               25          2
# 31            terms          2
# 32          provide          2
# 33             spam          2
# 34          testing          2
# 35    methodologies          2
# 36        estimates          2
# 37            tesla          1
# 38             elon          1
# 39          raising          1
# 40         obstacle          1
# 41              bid          1
# 42             twtr          1
# 43              sec          1
# 44           filing          1
# 45         released          1
# 46          morning          1
# 47          counsel          1
# 48          coughed          1
# 49       committing          1
# 50            based          1
# 51         behavior          1
# 52             date          1
# 53   correspondence          1
# 54         believes          1
# 55         actively          1
# 56        resisting          1
# 57        thwarting          1
# 58         reserves          1
# 59        resulting          1
# 60        therefrom          1
# 61        including          1
# 62        terminate          1
# 63            stock          1
# 64             fell          1
# 65             news          1
# 66        complaint          1
# 67            stems          1
# 68       insistence          1
# 69           social          1
# 70            media          1
# 71            world          1
# 72          richest          1
# 73           person          1
# 74          flagged          1
# 75       announcing          1
# 76          acquire          1
# 77               54          1
# 78               20          1
# 79            april          1
# 80           shares          1
# 81          dropped          1
# 82               17          1
# 83        announced          1
# 84        statement          1
# 85            yahoo          1
# 86          finance          1
# 87     spokesperson          1
# 88         continue          1
# 89    cooperatively          1
# 90       accordance          1
# 91     shareholders          1
# 92           intend          1
# 93            close          1
# 94          enforce          1
# 95           agreed          1
# 96            price          1
# 97            weeks          1
# 98           raised          1
# 99         concerns          1
# 100            user          1
# 101            base          1
# 102     challenging          1
# 103        veracity          1
# 104        reported          1
# 105             mid          1
# 106        famously          1
# 107       responded          1
# 108          thread          1
# 109           parag          1
# 110         agrawal          1
# 111       outlining          1
# 112         current          1
# 113       processes          1
# 114            poop          1
# 115           emoji          1
# 116           month          1
# 117      calculates          1
# 118       estimated          1
# 119      suspicious          1
# 120            team          1
# 121       providing          1
# 122          access          1
# 123          bottom          1
# 124          noting          1
# 125         letters          1
# 126              31          1
# 127         refused          1
# 128      repeatedly          1
# 129               9          1
# 130            2022          1
# 131      facilitate          1
# 132      evaluation          1
# 133            fake          1
# 134        accounts          1
# 135           offer          1
# 136          simply          1
# 137      additional          1
# 138         details          1
# 139         written          1
# 140       materials          1
# 141          verbal          1
# 142    explanations          1
# 143      tantamount          1
# 144        refusing          1
# 145        requests          1
# 146          effort          1
# 147    characterize          1
# 148         attempt          1
# 149       obfuscate          1
# 150         confuse          1
# 151             lax          1
# 152         conduct          1
# 153        analysis          1
# 154            adds          1
# 155       confident          1
# 156      publicized          1
# 157      understand          1
# 158      reluctance          1
# 159   independently          1
# 160        evaluate          1
# 161               1          1
# 162             fee          1
# 163           calls          1
# 164        contract          1
# 165          change          1
# 166         penalty          1

# %%
#Extractive text summarization model

import nltk
from nltk.corpus import stopwords
from nltk.cluster.util import cosine_distance
import numpy as np
import networkx as nx

nltk.download('stopwords')

def read_article(text):        
  sentences =[]        
  sentences = sent_tokenize(text)    
  for sentence in sentences:        
    sentence.replace("[^a-zA-Z0-9]"," ")  
  return sentences

def sentence_similarity(sent1,sent2,stopwords=None):    
  if stopwords is None:        
    stopwords = []        
  sent1 = [w.lower() for w in sent1]    
  sent2 = [w.lower() for w in sent2]
        
  all_words = list(set(sent1 + sent2))   
     
  vector1 = [0] * len(all_words)    
  vector2 = [0] * len(all_words)        
  #build the vector for the first sentence    
  for w in sent1:        
    if not w in stopwords:
      vector1[all_words.index(w)]+=1                                                             
  #build the vector for the second sentence    
  for w in sent2:        
    if not w in stopwords:            
      vector2[all_words.index(w)]+=1 
               
  return 1-cosine_distance(vector1,vector2)

def build_similarity_matrix(sentences,stop_words):
  #create an empty similarity matrix
  similarity_matrix = np.zeros((len(sentences),len(sentences)))
  for idx1 in range(len(sentences)):
      for idx2 in range(len(sentences)):
        if idx1!=idx2:
          similarity_matrix[idx1][idx2] = sentence_similarity(sentences[idx1],sentences[idx2],stop_words)
  return similarity_matrix

def generate_summary(text,top_n):
  stop_words = stopwords.words('english')    
  summarize_text = []
  # Step1: read text and tokenize    
  sentences = read_article(text)
  # Step2: generate similarity matrix            
  sentence_similarity_matrix = build_similarity_matrix(sentences,stop_words)
  # Step3: Rank sentences in similarity matrix
  sentence_similarity_graph = nx.from_numpy_array(sentence_similarity_matrix)
  scores = nx.pagerank(sentence_similarity_graph)
  # Step4: sort the rank and place top sentences
  ranked_sentences = sorted(((scores[i],s) for i,s in enumerate(sentences)),reverse=True)
  
  # Step5: get the top n number of sentences based on rank
  for i in range(top_n):
    summarize_text.append(ranked_sentences[i][1])
  # Step6 : output the summarized version
  return " ".join(summarize_text),len(sentences)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
generate_summary(clean_news, 3)
# Out:
# ('"Twitter stock fell around 5% on the news.Musk\'s complaint stems from Twitter\'s insistence that the social media platform does not have a problem with bots, an issue that the world\'s richest person has flagged since announcing a deal to acquire Twitter for $54.20 per share on April 25. "Over the last several weeks, Musk has raised various concerns about Twitter\'s user base, challenging the veracity of the company\'s claims that just 5% of its reported users are bots.In mid-May, Musk famously responded to a thread from Twitter CEO Parag Agrawal outlining the company\'s current processes with a poop emoji. "The letter later adds that if Twitter "is confident in its publicized spam estimates, Mr. Musk does not understand the company’s reluctance to allow Mr. Musk to independently evaluate those estimates.',
#  17)

# %%
#Abstractive text summarizer 

import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation
from heapq import nlargest

def summarize(text, per):
    
    nlp = spacy.load('en_core_web_sm')
    
    doc= nlp(text)
    
    tokens=[token.text for token in doc]
    
    word_frequencies={}
    
    for word in doc:
        if word.text.lower() not in list(STOP_WORDS):
            if word.text.lower() not in punctuation:
                if word.text not in word_frequencies.keys():
                    word_frequencies[word.text] = 1
                else:
                    word_frequencies[word.text] += 1
    max_frequency=max(word_frequencies.values())

    for word in word_frequencies.keys():
        word_frequencies[word]=word_frequencies[word]/max_frequency
    
    sentence_tokens= [sent for sent in doc.sents]
    
    sentence_scores = {}
    
    for sent in sentence_tokens:
        for word in sent:
            if word.text.lower() in word_frequencies.keys():
                if sent not in sentence_scores.keys():                            
                    sentence_scores[sent]=word_frequencies[word.text.lower()]
                else:
                    sentence_scores[sent]+=word_frequencies[word.text.lower()]
    
    select_length=int(len(sentence_tokens)*per)
    
    summary=nlargest(select_length, sentence_scores,key=sentence_scores.get)
    
    final_summary=[word.text for word in summary]
    
    summary=''.join(final_summary)
    
    return summary

# %%
summarize(clean_news, 0.30)
# Out:
# '"Musk\'s team now claims that Twitter is not providing access to information that could get to the bottom of these claims, noting that Musk requested data from Twitter in letters sent to the company on May 25 and May 31."Twitter has, in fact, refused to provide the information that Mr. Musk has repeatedly requested since May 9, 2022 to facilitate his evaluation of spam and fake accounts on the company’s platform," Monday\'s letter reads.Tesla CEO Elon Musk is raising another obstacle in his $44 billion bid to buy Twitter (TWTR).In an SEC filing released Monday morning, Musk\'s counsel said Twitter has not coughed up adequate data on the company\'s users, committing a "clear material breach" of the company\'s obligations as part of its merger agreement."Based on Twitter’s behavior to date, and the company’s latest correspondence in particular, Mr. Musk believes the company is actively resisting and thwarting his information rights (and the company’s corresponding obligations) under the merger agreement," the letter reads."This is a clear material breach of Twitter’s obligations under the merger agreement and Mr. Musk reserves all rights resulting therefrom, including his right not to consummate the transaction and his right to terminate the merger agreement.In a statement to Yahoo Finance on Monday, a Twitter spokesperson said: "Twitter has and will continue to cooperatively share information with Mr. Musk to consummate the transaction in accordance with the terms of the merger agreement.'

# %% [markdown]
# #Q2 - Text Classification

# %% [markdown]
# Insurance industry is highly sensitive about Epidemic disease. A disease outbreak implying potential of high claims cases to insurer, hence resulting in financial loss. AIA being a major insurer in Asia pacific region, we have to always keep a close eye on epidemic trend and carry out pre-emptive action if any unusual trend been observed. Our claims department colleague deems social media is a good 3rd party source where we can obtain epidemic information. This data will complement and provide additional dimension for business decision making. However, to eyeball each single thread online and record down the topic category is time consuming and resource intensive, therefore, business user then reaches out to Data Science team and seek for a more effective solution. As a Data Scientist, you are required to:
#
#
# 1.   Develop a text classifier model to help classify conversation topic from social media.
# 2.   Include any interesting insight that you observe from the dataset based on your analysis.
# 3.   Be mindful your target audience is business user; your final model output and business insight need to be easily understandable.
#
# *To ease your development, a covid 19 dataset (with label) will be provide. You shall use this dataset for your model development.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/atlas-github/aia_2022/main/Q2%20Dataset.csv")
df
# Out:
#                    tweet_id  \
# 0      '497671828195008512'
# 1      '522457018863726592'
# 2      '523158748958031873'
# 3      '522494238815031296'
# 4      '523510656771698689'
# ...                     ...
# 10553           1.25514E+18
# 10554           1.25514E+18
# 10555           1.25514E+18
# 10556           1.25514E+18
# 10557           1.25514E+18
#
#                                               tweet_text  \
# 0      RT @QuestionsNG: Ebola is not gonna come close...
# 1      It's too funny to watch MSNBC put an infectiou...
# 2      RT @mikecalma: How the #GOP fights infectious ...
# 3      @drbrainbugz it's all about spin! Guaranteed t...
# 4      WHO officially declares that #Senegal has ende...
# ...                                                  ...
# 10553  RT @KateSzumanski: During these unprecedented ...
# 10554  "Kinda lacking" @curefinder It's okay to just ...
# 10555  out now check this out on youtube\n#YouthWithY...
# 10556  RT @the_righty: -Shivsena Supporters beat up M...
# 10557  RT @Jerusalem_Post: #Israel will celebrate its...
#
#                            topic  label
# 0       other_useful_information      6
# 1                      treatment      3
# 2       other_useful_information      6
# 3       other_useful_information      6
# 4           disease_transmission      1
# ...                          ...    ...
# 10553  not_related_or_irrelevant      7
# 10554  not_related_or_irrelevant      7
# 10555  not_related_or_irrelevant      7
# 10556  not_related_or_irrelevant      7
# 10557  not_related_or_irrelevant      7
#
# [10558 rows x 4 columns]

# %%
#find out number of labels for each topic
import seaborn as sns
sns.set(rc = {'figure.figsize':(23,8)})
ax = sns.countplot(x="topic", data=df)

# %%
#remove stopwords and create new column

# Import stopwords with nltk.
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#remove all Twitter handles
df["tweet_text_clean"] = df["tweet_text"].str.replace('(@\w+.*?)',"")

#remove all Twitter RTs
df["tweet_text_clean"] = df["tweet_text_clean"].str.replace('RT :',"")

#remove &amp;
df["tweet_text_clean"] = df["tweet_text_clean"].str.replace('&amp;',"")

#remove all hyperlinks
df["tweet_text_clean"] = df["tweet_text_clean"].str.replace('http\S+|www.\S+', '', case=False)

#remove all non-ascii characters
df["tweet_text_clean"] = df["tweet_text_clean"].str.encode('ascii', 'ignore').str.decode('ascii')

#remove all puntuation within tweet_text_clean
df["tweet_text_clean"] = df["tweet_text_clean"].str.replace(r'[^\w\s]+', '')

#lower case tweet_text_clean column
df["tweet_text_clean"] = df["tweet_text_clean"].str.lower()

#remove all leading and trailing white spaces
df["tweet_text_clean"]  = df["tweet_text_clean"].str.strip()

#remove all stopwords
df["tweet_text_clean"] = df["tweet_text_clean"].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: FutureWarning: The default value of regex will change from True to False in a future version.
#                    tweet_id  \
# 0      '497671828195008512'
# 1      '522457018863726592'
# 2      '523158748958031873'
# 3      '522494238815031296'
# 4      '523510656771698689'
# ...                     ...
# 10553           1.25514E+18
# 10554           1.25514E+18
# 10555           1.25514E+18
# 10556           1.25514E+18
# 10557           1.25514E+18
#
#                                               tweet_text  \
# 0      RT @QuestionsNG: Ebola is not gonna come close...
# 1      It's too funny to watch MSNBC put an infectiou...
# 2      RT @mikecalma: How the #GOP fights infectious ...
# 3      @drbrainbugz it's all about spin! Guaranteed t...
# 4      WHO officially declares that #Senegal has ende...
# ...                                                  ...
# 10553  RT @KateSzumanski: During these unprecedented ...
# 10554  "Kinda lacking" @curefinder It's okay to just ...
# 10555  out now check this out on youtube\n#YouthWithY...
# 10556  RT @the_righty: -Shivsena Supporters beat up M...
# 10557  RT @Jerusalem_Post: #Israel will celebrate its...
#
#                            topic  label  \
# 0       other_useful_information      6
# 1                      treatment      3
# 2       other_useful_information      6
# 3       other_useful_information      6
# 4           disease_transmission      1
# ...                          ...    ...
# 10553  not_related_or_irrelevant      7
# 10554  not_related_or_irrelevant      7
# 10555  not_related_or_irrelevant      7
# 10556  not_related_or_irrelevant      7
# 10557  not_related_or_irrelevant      7
#
#                                         tweet_text_clean
# 0      ebola gonna come close friends family members ...
# 1      funny watch msnbc put infectious disease split...
# 2                    gop fights infectious disease ebola
# 3      spin guaranteed tho questions raised role post...
# 4      officially declares senegal ended ebola transm...
# ...                                                  ...
# 10553  unprecedented times college students continue ...
# 10554  kinda lacking okay say federal government lack...
# 10555  check youtube youthwithyou youtube music hipho...
# 10556  shivsena supporters beat man shaved head criti...
# 10557  israel celebrate 72nd birthday lockdown need k...
#
# [10558 rows x 5 columns]

# %%
#download to review tweet_text_clean column
df.to_csv("df.csv")
from google.colab import files
files.download("df.csv")

# %%
from collections import Counter
Counter(" ".join(df[df["topic"] == "disease_signs_or_symptoms"]["tweet_text_clean"]).split()).most_common(20)
# Out:
# [('symptoms', 372),
#  ('ebola', 210),
#  ('mers', 93),
#  ('patient', 84),
#  ('signs', 66),
#  ('virus', 66),
#  ('coronavirus', 48),
#  ('hospital', 43),
#  ('ebolalike', 42),
#  ('fever', 37),
#  ('showing', 29),
#  ('patients', 27),
#  ('us', 27),
#  ('covid19', 27),
#  ('disease', 26),
#  ('health', 24),
#  ('new', 23),
#  ('show', 23),
#  ('via', 23),
#  ('2', 22)]

# %%
Counter(" ".join(df[df["topic"] == "disease_transmission"]["tweet_text_clean"]).split()).most_common(20)
# Out:
# [('transmission', 204),
#  ('mers', 191),
#  ('ebola', 163),
#  ('spread', 139),
#  ('virus', 128),
#  ('disease', 108),
#  ('coronavirus', 107),
#  ('spreads', 50),
#  ('us', 48),
#  ('people', 43),
#  ('covid19', 43),
#  ('evidence', 34),
#  ('new', 33),
#  ('corona', 33),
#  ('first', 31),
#  ('human', 30),
#  ('cdc', 29),
#  ('via', 29),
#  ('case', 29),
#  ('infected', 28)]

# %%
Counter(" ".join(df[df["topic"] == "treatment"]["tweet_text_clean"]).split()).most_common(20)
# Out:
# [('ebola', 315),
#  ('treatment', 292),
#  ('coronavirus', 161),
#  ('covid19', 94),
#  ('patients', 74),
#  ('us', 64),
#  ('vaccine', 59),
#  ('virus', 59),
#  ('mers', 51),
#  ('disease', 42),
#  ('treatments', 42),
#  ('new', 40),
#  ('drug', 38),
#  ('hospital', 34),
#  ('experimental', 32),
#  ('cure', 31),
#  ('testing', 31),
#  ('news', 27),
#  ('medical', 27),
#  ('tests', 26)]

# %%
Counter(" ".join(df[df["topic"] == "deaths_reports"]["tweet_text_clean"]).split()).most_common(20)
# Out:
# [('death', 353),
#  ('toll', 329),
#  ('coronavirus', 327),
#  ('deaths', 229),
#  ('covid19', 133),
#  ('us', 97),
#  ('new', 91),
#  ('uk', 71),
#  ('people', 69),
#  ('died', 64),
#  ('cases', 58),
#  ('total', 57),
#  ('daily', 46),
#  ('ebola', 45),
#  ('disease', 44),
#  ('reported', 41),
#  ('news', 39),
#  ('breaking', 35),
#  ('rate', 33),
#  ('dead', 32)]

# %%
Counter(" ".join(df[df["topic"] == "prevention"]["tweet_text_clean"]).split()).most_common(20)
# Out:
# [('ebola', 188),
#  ('spread', 184),
#  ('prevention', 155),
#  ('covid19', 134),
#  ('coronavirus', 131),
#  ('virus', 78),
#  ('disease', 69),
#  ('prevent', 64),
#  ('health', 63),
#  ('mers', 59),
#  ('help', 56),
#  ('stop', 55),
#  ('corona', 52),
#  ('masks', 50),
#  ('stay', 49),
#  ('social', 43),
#  ('face', 41),
#  ('measures', 38),
#  ('distancing', 38),
#  ('home', 36)]

# %%
Counter(" ".join(df[df["topic"] == "affected_people"]["tweet_text_clean"]).split()).most_common(20)
# Out:
# [('cases', 509),
#  ('mers', 355),
#  ('disease', 292),
#  ('coronavirus', 284),
#  ('us', 223),
#  ('covid19', 213),
#  ('new', 211),
#  ('case', 210),
#  ('virus', 159),
#  ('symptoms', 150),
#  ('confirmed', 142),
#  ('total', 132),
#  ('ebola', 129),
#  ('positive', 126),
#  ('deaths', 118),
#  ('first', 110),
#  ('saudi', 101),
#  ('patient', 97),
#  ('deadly', 94),
#  ('arabia', 93)]

# %%
Counter(" ".join(df[df["topic"] == "other_useful_information"]["tweet_text_clean"]).split()).most_common(20)
# Out:
# [('ebola', 519),
#  ('disease', 510),
#  ('coronavirus', 414),
#  ('mers', 380),
#  ('virus', 311),
#  ('covid19', 255),
#  ('questions', 233),
#  ('health', 199),
#  ('spread', 182),
#  ('deadly', 161),
#  ('us', 138),
#  ('middle', 117),
#  ('new', 115),
#  ('pandemic', 96),
#  ('news', 92),
#  ('outbreak', 91),
#  ('question', 88),
#  ('world', 88),
#  ('diseases', 87),
#  ('people', 81)]

# %%
Counter(" ".join(df[df["topic"] == "not_related_or_irrelevant"]["tweet_text_clean"]).split()).most_common(20)
# Out:
# [('coronavirus', 1219),
#  ('covid19', 1063),
#  ('spread', 854),
#  ('corona', 513),
#  ('people', 290),
#  ('virus', 266),
#  ('new', 182),
#  ('us', 176),
#  ('time', 174),
#  ('help', 169),
#  ('like', 162),
#  ('dont', 146),
#  ('get', 127),
#  ('one', 126),
#  ('home', 123),
#  ('please', 121),
#  ('today', 120),
#  ('pandemic', 116),
#  ('stay', 115),
#  ('know', 112)]

# %% [markdown]
# ##Insight

# %%
# !git clone https://github.com/atlas-github/aia_2022
# Out:
# Cloning into 'aia_2022'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 14 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (14/14), done.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

#venn.png was drawn using PowerPoint
img = mpimg.imread('aia_2022/venn.png')
f = plt.figure(figsize=(45,13.5))
plt.axis('off')
imgplot = plt.imshow(img)
plt.show()

# %%
#to download venn.png
files.download("aia_2022/venn.png")

# %% [markdown]
# ##Model

# %% [markdown]
# `df` was uploaded into Google Natural Language API. The API endpoint is
